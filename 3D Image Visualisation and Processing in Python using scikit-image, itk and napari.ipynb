# %% [markdown]
# # Based on https://git.mpi-cbg.de/rhaase/lecture_applied_bioimage_analysis_2020/tree/master/12_Volumetric_image_data

# %% [markdown]
# # Also watch https://www.youtube.com/watch?v=lRtGqc5r6O0

# %% [markdown]
# # Loading, processing and visualising 3D images
# with scikit-image, numpy and matplotlib

# %%
from skimage.io import imread

image = imread('/Users/fernandes/Documents/Data/000200.raw.tif')

# print out the spatial dimensions of the image
print(image.shape)
# Out:
# (111, 1024, 512)

# %%
import matplotlib.pyplot as plt 

''' A 3D image cannot be open as such'''
plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2cb62ca16e1e> in <module>
#       2
#       3 ''' A 3D image cannot be open as such'''
# ----> 4 plt.imshow(image)
#       5 plt.show()
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# ~/anaconda3/envs/napari/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     697                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     698             raise TypeError("Invalid shape {} for image data"
# --> 699                             .format(self._A.shape))
#     700
#     701         if self._A.ndim == 3:
#
# TypeError: Invalid shape (111, 1024, 512) for image data

# %% [markdown]
# Showing it slice by slice

# %%
import matplotlib.pyplot as plt 

plt.imshow(image[0])
plt.show()

plt.imshow(image[25])
plt.show()

plt.imshow(image[50])
plt.show()

plt.imshow(image[100])
plt.show()

# %% [markdown]
# Maximum projection

# %%
import numpy as np

max_z = np.max(image, axis=0)
plt.imshow(max_z)
plt.show()

max_y = np.max(image, axis=1)
plt.imshow(max_y)
plt.show()

max_x = np.max(image, axis=2)
plt.imshow(max_x)
plt.show()

# %%
'''Need to adjust aspect for x an y dimensions'''

voxel_size_x = 0.52
voxel_size_y = 0.52
voxel_size_z = 2

aspect_xz = voxel_size_z / voxel_size_x
aspect_yz = voxel_size_z / voxel_size_y

def showXYZprojection(image):
    max_z = np.max(image, axis=0)
    plt.imshow(max_z)
    plt.show()

    max_y = np.max(image, axis=1)
    plt.imshow(max_y, aspect=aspect_xz)
    plt.show()

    max_x = np.max(image, axis=2)
    plt.imshow(max_x, aspect=aspect_yz)
    plt.show()

showXYZprojection(image)

# %% [markdown]
# # Visualisation with itkWidgets

# %%
from itkwidgets import view

view(image)
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, point_sets=[], rendered_image=<itk.itkImagePython.itkImageF3; pro…

# %%
import itk

# convert our image into a proper itk_image
itk_image = itk.image_view_from_array(image)
itk_image.SetSpacing([voxel_size_x, voxel_size_y, voxel_size_z])

view(itk_image)
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, point_sets=[], rendered_image=<itk.itkImagePython.itkImageF3; pro…

# %%
print (image)
# Out:
# [[[ 99. 102. 100. ... 101. 101. 100.]
#   [103. 100.  99. ...  99.  99.  98.]
#   [ 99. 102.  99. ... 101. 101.  99.]
#   ...
#   [102. 100. 101. ... 100.  99. 103.]
#   [102. 101. 100. ... 102. 100. 100.]
#   [101. 102. 102. ... 101.  99.  99.]]
#
#  [[100.  99.  99. ...  99. 100. 100.]
#   [ 99. 100. 100. ...  99.  98.  99.]
#   [ 99.  99.  98. ...  99. 100.  99.]
#   ...
#   [ 99. 101.  98. ...  99.  98.  99.]
#   [ 99.  98. 100. ... 101.  98. 100.]
#   [ 99. 101. 100. ...  99. 100.  98.]]
#
#  [[ 99.  99.  98. ...  99.  98.  98.]
#   [ 98.  98.  99. ...  99.  98.  98.]
#   [ 98.  97.  99. ...  99. 100.  98.]
#   ...
#   [100. 100. 100. ...  99.  98.  99.]
#   [ 99.  98.  99. ...  99. 100.  99.]
#   [100.  98.  98. ...  99.  99.  99.]]
#
#  ...
#
#  [[ 98.  99.  98. ...  99.  99.  99.]
#   [ 99.  99. 100. ...  98.  97.  99.]
#   [ 99.  99.  99. ...  99.  98.  99.]
#   ...
#   [ 99.  99.  99. ...  99.  98.  99.]
#   [100.  99.  99. ... 100. 100.  98.]
#   [100. 100.  99. ...  99.  99.  98.]]
#
#  [[ 99. 100.  97. ... 100.  99.  99.]
#   [ 98.  97.  99. ...  99.  98.  99.]
#   [ 99.  99.  98. ...  98.  99.  98.]
#   ...
#   [100.  98. 100. ...  99.  97.  98.]
#   [ 99.  99.  99. ...  99.  98.  99.]
#   [100. 100.  98. ...  99.  98. 100.]]
#
#  [[ 99.  98.  98. ... 100.  99. 100.]
#   [ 98. 100.  98. ...  98.  98.  99.]
#   [ 99.  99.  99. ...  99.  98.  99.]
#   ...
#   [ 99.  99.  99. ...  99.  99.  98.]
#   [ 99.  98.  98. ...  99.  98.  98.]
#   [100. 100.  99. ... 100.  99.  99.]]]

# %% [markdown]
# ## Background subtraction

# %%
from skimage import morphology

structuring_element = np.ones((5,5,5))

background_subtracted_image = morphology.white_tophat(image, structuring_element)

showXYZprojection(background_subtracted_image)

# %% [markdown]
# # Napari
# Launching a Napari viewer

# %%
import napari

# initialize napari 
# graphical user interface (GUI)
napari.gui_qt()

# %%
# %gui qt

# %%
# Create an empty viewer
viewer = napari.Viewer()

# %%
# Add a new layer containing an image
viewer.add_image(image);

# %%
# Remove all layers to start from scratch
for l in viewer.layers:
    viewer.layers.remove(l)

# %%
# add the image again with scaling
viewer.add_image(image, scale=(aspect_xz, 1, 1))
# Out:
# <Image layer 'image' at 0x18389d410>

# %%
# Add a new layer containing an image
viewer.add_image(background_subtracted_image, scale=(aspect_xz, 1, 1))
# Out:
# <Image layer 'background_subtracted_image' at 0x1837532d0>

# %%
from skimage.filters import gaussian
blurred_image = gaussian(background_subtracted_image, sigma=1)

# Add to napari
viewer.add_image(blurred_image, scale=(aspect_xz, 1, 1))
# Out:
# <Image layer 'blurred_image' at 0x185070050>

# %%
from skimage import feature

peak_local_max = feature.peak_local_max(
    blurred_image,
    footprint=np.ones((7, 7, 3), dtype=np.bool),
    indices=False,
    threshold_rel=0.25
)
peaks = np.nonzero(peak_local_max)
print(len(peaks[0]))
# Out:
# 2191

# %% [markdown]
# Check the number of points above before proceeding. If it's too many, Napari may become irresponsive.

# %%
viewer.add_points(np.array(peaks).T, name='peaks', size=10, face_color='red');
